# %% [markdown]
# <a href="https://colab.research.google.com/github/sid2002-N/Transformers/blob/main/Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import turtle

# %%
import torch

# Check if the notebook is using the GPU
cuda_available = torch.cuda.is_available()
print(f"CUDA Available: {cuda_available}")

if cuda_available:
    # Print the name of the GPU assigned by Google
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")

    # Simple test: Move a tensor to GPU
    x = torch.tensor([1.0, 2.0]).cuda()
    print(f"Tensor is on: {x.device}")
else:
    print("GPU not detected. Go to 'Runtime' -> 'Change runtime type' and select GPU.")
# Out:
# CUDA Available: False
# GPU not detected. Go to 'Runtime' -> 'Change runtime type' and select GPU.
