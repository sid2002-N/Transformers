# %% [markdown]
# <a href="https://colab.research.google.com/github/sid2002-N/Transformers/blob/main/Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import turtle

# %%
import torch
print(torch.cuda.is_available())       # should print True
print(torch.cuda.get_device_name(0))   # should print RTX 3050
# Out:
# False
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_17164/150716996.py in <cell line: 0>()
#       1 import torch
#       2 print(torch.cuda.is_available())       # should print True
# ----> 3 print(torch.cuda.get_device_name(0))   # should print RTX 3050
#
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py in get_device_name(device)
#     597         str: the name of the device
#     598     """
# --> 599     return get_device_properties(device).name
#     600
#     601
#
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py in get_device_properties(device)
#     630         _CudaDeviceProperties: the properties of the device
#     631     """
# --> 632     _lazy_init()  # will define _get_device_properties
#     633     device = _get_device_index(device, optional=True)
#     634     if device < 0 or device >= device_count():
#
# ...
